# %%
ls
# Out:
# __pycache__/  layers.py  main.py  utils.py  yelp.ipynb

# %%
pwd
# Out:
# '/root/autodl-tmp/yelp_model'

# %%
# !python layers.py

# %%
# !python main.py
# Out:
# Done loading data from cached files.
# /root/autodl-tmp/yelp_model/main.py:157: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:78.)
#   loss = net.loss(batch_nodes, Variable(torch.cuda.LongTensor(batch_label)))
# Epoch: 0, loss: 0.8890148301919302
# GNN acc: 0.6096
# GNN auc: 0.7846
# GNN precision: 0.5975
# GNN a_precision: 0.3822
# GNN Recall: 0.6961
# GNN f1_score: 0.5469
# Epoch: 1, loss: 0.5817622360255983
# GNN acc: 0.6871
# GNN auc: 0.8171
# GNN precision: 0.6207
# GNN a_precision: 0.4454
# GNN Recall: 0.7333
# GNN f1_score: 0.6054
# Epoch: 2, loss: 0.5268710619873471
# GNN acc: 0.7582
# GNN auc: 0.8447
# GNN precision: 0.6522
# GNN a_precision: 0.4936
# GNN Recall: 0.7683
# GNN f1_score: 0.6634
# Epoch: 3, loss: 0.49574046002493966
# GNN acc: 0.7500
# GNN auc: 0.8541
# ...
