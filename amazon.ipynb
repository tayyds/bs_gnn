# %%
ls
# Out:
# __pycache__/  amazon.ipynb  layers.py  main.py  run.txt  utils.py

# %%
# !python layers.py

# %%
# !python main.py
# Out:
# Done loading data from cached files.
# /root/autodl-tmp/amazon_model/main.py:160: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:78.)
#   label_n0 = Variable(torch.cuda.LongTensor(label_n0))
# Epoch: 0, loss: 1.3337933208261217
# GNN acc: 0.9568
# GNN auc: 0.8947
# GNN precision: 0.9624
# GNN a_precision: 0.8126
# GNN Recall: 0.7810
# GNN f1_score: 0.8447
# Epoch: 1, loss: 0.6623836713177818
# GNN acc: 0.9618
# GNN auc: 0.9017
# GNN precision: 0.8885
# GNN a_precision: 0.8178
# GNN Recall: 0.8899
# GNN f1_score: 0.8892
# Epoch: 2, loss: 0.5990590708596366
# GNN acc: 0.9684
# GNN auc: 0.9212
# GNN precision: 0.9201
# GNN a_precision: 0.8304
# GNN Recall: 0.8909
# GNN f1_score: 0.9048
# Epoch: 3, loss: 0.6124661649976458
# GNN acc: 0.9728
# GNN auc: 0.9468
# GNN precision: 0.9558
# ...
